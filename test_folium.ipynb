# %%
import folium
import pandas as pd
import numpy as np

# %%
coordinates = pd.read_csv('data/coords_utm_montguers.csv')
coordinates.head()
# Out:
#     latitude  longitude
# 0  44.319380   5.472555
# 1  44.319021   5.472540
# 2  44.319105   5.472795
# 3  44.318835   5.472783
# 4  44.320991   5.472999

# %%
coordinates.shape
# Out:
# (2899, 2)

# %%
np.random.seed(0)
random_idxs = np.random.choice(len(coordinates), size=100, replace=False)
random_idxs
# Out:
# array([2124,  666,   22,  104,  702, 1423,  483,   92, 1379, 2231, 1861,
#         302,  652,  436, 1965,  352,  628, 2416,  995, 1885, 1368, 1947,
#        2104, 1783, 1323,  682,  599,  762,  248,  688, 1266, 2179,  806,
#         905,  791, 1077,  553, 2853,  422, 1895, 2846, 2130, 1802, 2781,
#        2668, 1436, 2160, 2624, 2531,  118, 2880, 2312,  507,  937, 1968,
#        1271,  979,  890, 1775, 2461, 2144, 2481,  380, 2746, 1277,  182,
#        2032, 1715,  472, 1013,   33,  263,  748, 2513,  874,  138,  306,
#        2772, 2876,  899,  918,  600,  446,  117, 1560, 1282, 1757,  910,
#        2311,  410, 1284, 2000, 2438, 1235,  491, 2747,  311, 2683, 1665,
#         565])

# %%
random_coords = coordinates.iloc[random_idxs]
random_coords
# Out:
#        latitude  longitude
# 2124  44.295586   5.535359
# 666   44.320365   5.526269
# 22    44.314022   5.482988
# 104   44.309396   5.521535
# 702   44.311818   5.526027
# ...         ...        ...
# 2747  44.269564   5.547646
# 311   44.317894   5.524031
# 2683  44.287310   5.543149
# 1665  44.301701   5.531611
# 565   44.319300   5.525596
#
# [100 rows x 2 columns]

# %%
locationlist = random_coords.values.tolist()
print(len(locationlist))
print(locationlist[7])
# Out:
# 100
# [44.31686437143251, 5.521729912986216]

# %%
fmap = folium.Map(location=[44.304303, 5.506360], zoom_start=12)
for point in range(len(locationlist)):
    folium.Marker(locationlist[point]).add_to(fmap)
fmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...
